# %%
import pandas as pd

# %%
df1=pd.read_csv(
    "/Users/Harsh/Desktop/Uber_Movement/mumbai/Andheri_East/mumbai_Andheri_East_weekday_free_flow.csv",
    delimiter = ',')

# %%
df1
# Out:
#      sourceid  dstid  hod  mean_travel_time  time_period      lng_o  \
# 0         265    357    1            802.91            1  72.862368
# 1         265    357    2            789.04            1  72.862368
# 2         265    357    3            759.72            1  72.862368
# 3         265    357    4            778.56            1  72.862368
# 4         265    357    1            780.23            2  72.862368
# 5         265    357    2            741.30            2  72.862368
# 6         265    357    3            754.12            2  72.862368
# 7         265    357    4            784.80            2  72.862368
# 8         265    357    1            896.85            3  72.862368
# 9         265    357    2            866.07            3  72.862368
# 10        265    357    3            839.22            3  72.862368
# 11        265    357    4            843.48            3  72.862368
# 12        265    357    1            837.83            4  72.862368
# ...

# %%
import numpy as np
df1["unique_id"] = 0

# %%
i = 0
group_of_twelve = 0
while (i<len(df1)): 
    df1.unique_id[i] = group_of_twelve*12 + df1.time_period[i]
    if ((df1.time_period[i]==12) & (df1.row_num[i]==df1.count_of_rows[i])):
        group_of_twelve = group_of_twelve+1
    i=i+1
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
df1
# Out:
#      sourceid  dstid  hod  mean_travel_time  time_period      lng_o  \
# 0         265    357    1            802.91            1  72.862368
# 1         265    357    2            789.04            1  72.862368
# 2         265    357    3            759.72            1  72.862368
# 3         265    357    4            778.56            1  72.862368
# 4         265    357    1            780.23            2  72.862368
# 5         265    357    2            741.30            2  72.862368
# 6         265    357    3            754.12            2  72.862368
# 7         265    357    4            784.80            2  72.862368
# 8         265    357    1            896.85            3  72.862368
# 9         265    357    2            866.07            3  72.862368
# 10        265    357    3            839.22            3  72.862368
# 11        265    357    4            843.48            3  72.862368
# 12        265    357    1            837.83            4  72.862368
# ...

# %%
df1.to_csv(
    path_or_buf="/Users/Harsh/Desktop/Uber_Movement/mumbai/Andheri_East/mumbai_Andheri_East_weekday_free_flow.csv",
    sep=',', index=False
    , header=True)
